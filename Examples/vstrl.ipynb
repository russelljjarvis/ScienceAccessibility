# %% [markdown]
# # Scientific readability project
# ## Difficulty of Reading Level of
# ### of Academic and Popular and Psuedo scientific Language
#
# authors: other_authors, ...,  Russell Jarvis
#
# https://github.com/russelljjarvis/
#
# rjjarvis@asu.edu

# %%
from bokeh.plotting import figure, output_file, show, ColumnDataSource
from bokeh.models import HoverTool
from bokeh.plotting import figure, output_file, show
# %matplotlib inline
from bokeh.plotting import show, output_notebook
from bokeh.models import ColumnDataSource, OpenURL, TapTool
import os
output_notebook()
os.system('jupyter trust Visualisation_search_terms_reading_levelGS.ipynb')
# Out:
# 'Communications From Elsewhere\nSkip to content\nCommunications From Elsewhere\nHome of RJL20\nMenu\nHome\nFacebook\nTwitter\nConstructive discourse in the works of Gibson\nHenry S. Cameron\nDepartment of Ontology, Harvard University\n1. Realities of fatal flaw\nIf one examines constructive discourse, one is faced with a choice: either\naccept capitalist desituationism or conclude that art is used to reinforce\ncapitalism. Therefore, the main theme of la Tournier’s[1]\nessay on substructural textual theory is the role of the reader as artist.\nIn the works of Gibson, a predominant concept is the concept of neodialectic\nreality. Sontag uses the term ‘constructive discourse’ to denote a textual\nwhole. It could be said that Foucault promotes the use of predialectic\nnarrative to modify society.\n“Narrativity is dead,” says Marx. The rubicon, and subsequent stasis, of\ncapitalist desituationism which is a central theme of Gibson’s Virtual\nLight emerges again in Idoru. Thus, several dematerialisms\nconcerning the role of the writer as poet may be found.\nThe characteristic theme of the works of Gibson is a mythopoetical reality.\nFoucaultist power relations implies that the purpose of the artist is social\ncomment. But the main theme of Cameron’s[2] analysis of\ncapitalist desituationism is the meaninglessness, and some would say the\nabsurdity, of postmaterial class.\nAny number of discourses concerning cultural objectivism exist. However, the\npremise of Foucaultist power relations holds that academe is part of the\nfailure of truth, but only if Bataille’s critique of neosemanticist capitalist\ntheory is invalid.\nThe characteristic theme of the works of Gibson is the bridge between\nsociety and sexual identity. It could be said that Reicher[3] implies that we have to choose between constructive\ndiscourse and predialectic materialism.\nThe subject is interpolated into a capitalist discourse that includes\nsexuality as a totality. Thus, an abundance of deconstructivisms concerning a\npostcultural reality may be discovered.\nMarx suggests the use of constructive discourse to challenge sexism. But if\nFoucaultist power relations holds, the works of Gibson are an example of\nmythopoetical Marxism.\nThe premise of dialectic rationalism suggests that truth is capable of\ntruth. Therefore, Derrida uses the term ‘capitalist desituationism’ to denote\nthe role of the writer as observer.\nConstructive discourse implies that government is impossible, given that\nculture is distinct from reality. It could be said that Baudrillard promotes\nthe use of capitalist desituationism to read and analyse culture.\n2. Constructive discourse and neotextual modern theory\n“Sexual identity is intrinsically used in the service of hierarchy,” says\nFoucault. Any number of narratives concerning neotextual modern theory exist.\nBut the premise of capitalist desituationism suggests that the raison d’etre of\nthe writer is deconstruction.\nLyotard uses the term ‘Foucaultist power relations’ to denote the absurdity,\nand therefore the fatal flaw, of postsemanticist society. It could be said that\nthe subject is contextualised into a capitalist desituationism that includes\nart as a whole.\nThe closing/opening distinction prevalent in Gibson’s Virtual Light\nis also evident in All Tomorrow’s Parties, although in a more cultural\nsense. In a sense, several situationisms concerning not narrative, but\nsubnarrative may be found.\n1. la Tournier, J. ed. (1972)\nThe Context of Futility: Capitalist desituationism in the works of\nKoons. O’Reilly & Associates\n2. Cameron, N. F. (1999) Constructive discourse and\ncapitalist desituationism. Panic Button Books\n3. Reicher, B. ed. (1985) Reinventing Expressionism:\nCapitalist desituationism and constructive discourse. Loompanics\nThe essay you have just seen is completely meaningless and was randomly generated by the Postmodernism Generator.\nTo generate another essay, follow this link.\nIf you liked this particular es ...

# %%
import mine_list
def process_dics(urlDats):
    dfs = []
    for urlDat in urlDats:
        if len(dfs) == 0:
            dfs = pd.DataFrame(pd.Series(urlDat)).T
        dfs = pd.concat([ dfs, pd.DataFrame(pd.Series(urlDat)).T ])
    return dfs


with open('unraveled_links.p','rb') as handle:
    unravel = pickle.load(handle)
print(unravel)

dfs = process_dics(unravel)
dfs
# Out:
# /opt/conda/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
# <_io.TextIOWrapper name='/home/jovyan/Examples/Transgenicask82.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/Transgenicgoogle79.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/Transgenicyahoo82.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/Transgenicgoogle82.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/Transgenicduckduckgo79.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/evolution_google_1.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/Transgenic_yahoo_92.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/autosomesduckduckgo17.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/neuromorphic hardwaregoogle30.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/evolution_duckduckgo_1.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/Transgenic_yahoo_96.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/Transgenicask79.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/neuromorphic hardwaregoogle49.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/Transgenicyahoo79.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/neuromorphic hardwareyahoo49.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/neuromorphic hardwareyahoo30.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/evolution_yahoo_1.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/prancercise philosophyyahoo59.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/neuromorphic hardwareask30.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/Transgenicduckduckgo82.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/neuromorphic hardwareask49.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/neuromorphic hardwareduckduckgo30.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/neuromorphic hardwareduckduckgo49.pdf' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/prancercise philosophy_wikipedia_34.html' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/photosysnthesis_duckduckgo_2.html' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/respiration_google_11.html' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/s jarvis optogeneticsscholar9.html' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/scrook rgerkin neuronduckduckgo5.html' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/scrook rgerkin neuronduckduckgo14.html' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/reality TV_duckduckgo_51.html' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/s jarvis optogeneticsscholar0.html' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/respiration_google_12.html' mode='r' encoding='UTF-8'>
# {'link': '/home/jovyan/Examples/scrook rgerkin neuronduckduckgo5.html', 'wcount': 469, 'english': True, 'science': False}
# <_io.TextIOWrapper name='/home/jovyan/Examples/scrook rgerkin neuronduckduckgo6.html' mode='r' encoding='UTF-8'>
# {'link': '/home/jovyan/Examples/reality TV_duckduckgo_51.html', 'wcount': 113, 'english': True, 'science': False}
# <_io.TextIOWrapper name='/home/jovyan/Examples/reality TV_duckduckgo_60.html' mode='r' encoding='UTF-8'>
# {'link': '/home/jovyan/Examples/reality TV_duckduckgo_60.html', 'wcount': 231, 'english': True, 'science': False}
# <_io.TextIOWrapper name='/home/jovyan/Examples/reality TV_duckduckgo_70.html' mode='r' encoding='UTF-8'>
# {'link': '/home/jovyan/Examples/scrook rgerkin neuronduckduckgo14.html', 'wcount': 822, 'english': True, 'science': False, 'uniqueness': 0.41888297872340424, 'info_density': 0.00437636761487965, 'scaled_info_density': 5.324048193284246e-06, 'sp': 0.13288651824366113, 'ss': 0.37028215831787265, 'standard': 18.0, 'gf': 18.566294919454773, 'penalty': 18.786316136288924}
# <_io.TextIOWrapper name='/home/jovyan/Examples/scrook rgerkin neuronduckduckgo15.html' mode='r' encoding='UTF-8'>
# {'link': '/home/jovyan/Examples/scrook rgerkin neuronduckduckgo15.html', 'wcount': 406, 'english': True, 'science': False}
# <_io.TextIOWrapper name='/home/jovyan/Examples/scrook rgerkin neuronduckduckgo16.html' mode='r' encoding='UTF-8'>
# {'link': '/home/jovyan/Examples/scrook rgerkin neuronduckduckgo16.html', 'wcount': 236, 'english': True, 'science': False}
# <_io.TextIOWrapper name='/home/jovyan/Examples/scrook rgerkin neuronduckduckgo17.html' mode='r' encoding='UTF-8'>
# {'link': '/home/jovyan/Examples/scrook rgerkin neuronduckduckgo17.html', 'wcount': 0, 'english': True, 'science': False}
# <_io.TextIOWrapper name='/home/jovyan/Examples/scrook rgerkin neurongoogle0.html' mode='r' encoding='UTF-8'>
# {'link': '/home/jovyan/Examples/prancercise philosophy_wikipedia_34.html', 'wcount': 965, 'english': True, 'science': False, 'uniqueness': 0.5261538461538462, 'info_density': 0.0044994375703037125, 'scaled_info_density': 4.662629606532344e-06, 'sp': 0.19101519395637043, 'ss': 0.5786563110092522, 'standard': 7.0, 'gf': 23.353846153846156, 'penalty': 15.946594581888702}
# {'link': '/home/jovyan/Examples/scrook rgerkin neurongoogle0.html', 'wcount': 236, 'english': True, 'science': False}
# <_io.TextIOWrapper name='/home/jovyan/Examples/prancercise philosophy_wikipedia_37.html' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/home/jovyan/Examples/scrook rgerkin neurongoogle1.html' mode='r' encoding='UTF-8'>
# {'link': '/home/jovyan/Examples/scrook rgerkin neurongoogle1.html', 'wcount': 0, 'english': True, 'science': False}
# <_io.TextIOWrapper name='/home/jovyan/Examples/scrook rgerkin neuronyahoo0.html' mode='r' encoding='UTF-8'>
# {'link': '/home/jovyan/Examples/scrook rgerkin neuronyahoo0.html', 'wcount': 236, 'english': True, 'science': False}
# {'link': '/home/jovyan/Examples/photosysnthesis_duckduckgo_2.html', 'wcount': 1717, 'english': True, 'science': False, 'uniqueness': 0.3700061462814997, 'info_density': 0.002079542500649857, 'scaled_info_density': 1.2111488064355602e-06, 'sp': 0.09656941232283704, 'ss': 0.4466976516634052, 'standard': 16.0, 'gf': 19.725053635280098, 'penalty': 18.40579388162629}
# <_io.TextIOWrapper name='/home/jovyan/Examples/photosysnthesis_duckduckgo_3.html' mode='r' encoding='UTF-8'>
# {'link': '/home/jovyan/Examples/reality TV_duckduckgo_70.html', 'wcount': 1944, 'english': True, 'science': False, 'uniqueness': 0.35645677694770544, 'info_density': 0.0021784514840700736, 'scaled_info_density': 1.1206026152623837e-06, 'sp': 0.16255893257485607, 'ss': 0.507957887830499, 'standard': 10.0, 'gf': 16.489376979936644, 'penalty': 13.915205310373675}
# <_io.TextIOWrapper name='/home/jovyan/Examples/reality TV_duckduckgo_79.html' mode='r' encoding='UTF-8'>
# {'link': '/home/jovyan/Examples/respiration_google
# {'link': '/home/jovyan/Examples/s jarvis optogeneticsscholar1.html', 'wcount': 8610, 'english': True, 'science': False, 'uniqueness': 0.26499670402109426, 'info_density': 0.00040227284155478453, 'scaled_info_density': 4.6721584384992396e-08, 'sp': 0.13459619461248096, 'ss': 0.4697911173155484, 'standard': 17.0, 'gf': 17.516759529082645, 'penalty': 17.862767076469353}
# <_io.TextIOWrapper name='/home/jovyan/Examples/s jarvis optogeneticsscholar2.html' mode='r' encoding='UTF-8'>
# ...
#  'sheite,, valid lick, I say.\n'
#  'Debra Pollack\n'
#  '10:33 AM\n'
#  'Small point here, but an EEG is not an ER Test (45A).\n'
#  'I had EKG/ECG which tripped me up.\n'
#  'Anonymous\n'
#  '2:42 PM\n'
#  'Speaking of neatness, I (honestly!) do crossword puzzles with my opposite '
#  'hand. Takes all types.\n'
#  'Anonymous\n'
#  '12:00 AM\n'
#  'My name is CARISIR WILLIAM, and I base in USA...My life is back!!!After 2 '
#  'years of Broken marriage, my husband left me with two kids . I feltlike my '
#  'life was about to end i almost committed suicide, i was emotionallydown for '
#  'a very long time. Thanks to a spell caster called Dr AIFEBO , whichi met '
#  'online. On one faithful day, as I was browsing through the internet,Icame '
#  'across allot of testimonies about this particular spell caster. Somepeople '
#  'testified that he brought their Ex lover back, some testified thathe '
#  'restores womb,cure cancer,and other sickness, some testified that he cancast '
#  'a spell to stop divorce and so on. i also come across one '
#  'particulartestimony,it was about a woman called Sonia,she testified about '
#  'how hebrought back her Ex lover in less than 2 days, and at the end of '
#  'hertestimony she dropped Dr AIFEBO e-mail address. After reading all '
#  'these,Idecided to give it a try. I contacted him via email and explained '
#  'myproblem to him. In just 48hours, my husband came back to me. We solved '
#  'ourissues, and we are even happier than before Dr AIFEBO, is really a gifted '
#  'manand i will not stop publishing him because he is a wonderful man... If '
#  'youhave a problem and you are looking for a real and genuine spell caster '
#  'tosolve all your problems for you. Try High dr. '
#  'aifabospelltemple@gmail.comanytime, he might be the answer to your problems. '
#  "Here's his contact:dr.aifebospelltemple@gmail.com\n"
#  'mellisa lopez\n'
#  '2:58 PM\n'
#  'Are you going through a mid-life crisis for example a '
#  "divorce,miscarriage,can't find love no need to worry "
#  'bravespellcaster@gmail.com can help you with any personal need.many people '
#  'will try to sugar coat the truth and give you false hope but not Dr.Brave he '
#  'will tell you the truth and nothing but the truth and keep your hopes high '
#  "and alive so, please dont waste your time and hope on somebody who doesn't "
#  'deserve it..Via Email: covenantsolutiontemple@gmail.comVia Mobile: '
#  '+2348071622464Via Website http://enchantedscents.tripod.com/lovespell/\n'
#  'rondo\n'
#  '9:53 AM\n'
#  'So many options available for spellcasters. Maybe I should take it up if I '
#  'ever retire.A bit tougher than earlier this week, but not that much. Two '
#  'write-overs with hENNA\n'
#  'and OSSa. Took a while to figure the first loop trick. Didn’t hate it, but '
#  'kinda weakish I think, certainly ATYPICAL.. Some decent fill, especially the '
#  'longish stuff.RCRUMB was a super-gimme as I own many – maybe even most – of '
#  'his comix. I have had Mr. Natural as a wallpaper on my work computer for '
#  'many, many years; the millenials haven’t a clue about it and even some of '
#  'the boomers seem to have forgotten (or are so “square” they never knew, '
#  'there are those types, you know).SEEMS like more French words than usual '
#  'this week and of late in general. Before long at this rate I’ll have another '
#  'language to go along with my Swedish, German, and Russian. Which is too much '
#  'going on inside the cranium (lotta Latin xwords too).\n'
#  'Burma Shave\n'
#  '11:38 AM\n'
#  'SEEYAIt GOESBAD. It WENTCOLD. It ain’t great,when your girlfriend you '
#  'ALIENATE.SEEMS that the nude PHOTOof your SELF caused her some WOE,and when '
#  'you TAKETEN you NAUSEATE.---\n'
#  'ARGUS LECHE\n'
#  'BS2\n'
#  '11:44 AM\n'
#  'ARGUS was an American maker of cameras and photographic products, founded in '
#  '1936 in Ann Arbor, Michigan.LECHE - use your imagination\n'
#  'spacecraft\n'
#  '11:56 AM\n'
#  'RCRUMB was my way in to this grid. Ah, those were the days.I agree about the '
#  '"tip of the tongue" clue: inexact at best. But once I grabbed the handle of '
#  'that I could just glance at 60a and write in ROLLERCOASTER, taking note '
#  'that, as OFL says, ROASTER is a thing--as is SHOE. So when I (finally!) '
#  'broke into the north half, that loop gave me fits. I had C__CKE...and so was '
#  'thinking chicken-something, or maybe cracked crab ("Can\'t we have both?"), '
#  'but nothing worked. No wonder: I was on the wrong loop! Eventually, after '
#  '"crack"ing the NE with FIREAWAY, there was the old PAPERAIRPLANE, but I was '
#  'greatly disappointed that the straight across answer was gibberish.That left '
#  'the double natick at 27d, A_NAS_I crossing A_C and S_R. Had not clue one '
#  "what any of those three were. You may argue this fashion designer's fame "
#  "till you're blue in the face, but this guy is outside the fashion "
#  'world...WAY outside. Out here, we never heard of her. Luckily, though, I '
#  'picked the two correct letters, hoping that ANNA was a first name and just '
#  'picking a vowel out of 6 (yes, I included Y).That worthy lady and '
#  'AMARNA--forced in on crosses--are true outliers to me; mayhap Thursday is '
#  'too early for them. On the other hand, you kids would probably think the '
#  'same about CRUMB.Oh well, "Keep on truckin!"\n'
#  'KG\n'
#  '12:53 PM\n'
#  'This comment has been removed by the author.\n'
#  'KG\n'
#  '12:54 PM\n'
#  'Where in Sac?\n'
#  'DMG\n'
#  '4:24 PM\n'
#  "I seem to be the only person in puzzledom who isn't familiar with RCRUMB, "
#  'and he repaid by messing up my solution. Mispelled ARGoS and a cOASTER at '
#  'the fair left me with (a) someone named RCcoMB and (b) wondering what was '
#  'meant by the loop "ollerc" which didn\'t seem to hook up anywhere.\n'
#  'Did get the equally unknown to me ANNASUI but only letter by letter from the '
#  'crosses. some you get-some you don,t, but the challenge keeps me coming '
#  'back!\n'
#  'rain forest\n'
#  '6:34 PM\n'
#  'Great fun!\n'
#  'Loved it.Cute and novel theme, nice range of cluing, and virtually no crap.\n'
#  "LAE was a gimme, as was RCRUMB, and I wasn't bothered in the slightest by "
#  'PAIRPLANE.\n'
#  'leftcoastTAM\n'
#  '6:41 PM\n'
#  'Got the theme at ROLLERCOASTER, and it certainly helped in figuring out that '
#  'this was not a rebus. LAE sunk me, and LAi caused me to misspell NAUSiATE. '
#  'Otherwise an enjoyable puzzle, though it ate up a chunk of my afternoon.\n'
#  'Confluence Solutions\n'
#  '6:50 AM\n'
#  'Nice Article We\n'
#  'are providing Online Pogo Games Support,, Support for Pogo Games, Fix Pogo '
#  'Java Errors, Pogo Technical Support Call Toll Free Phone Number '
#  '1-888-221-6490 visit now\n'
#  'Pogo Games Support Toll Free Phone Number 1-888-221-6490\n'
#  'knight\n'
#  '2:16 AM\n'
#  'Very useful article. We provide the users 24x7 pogo gaming online support at '
#  'pogo gaming support\n'
#  'Post a Comment\n'
#  'Newer Post\n'
#  'Older Post\n'
#  'Home\n'
#  'Subscribe to:\n'
#  'Post Comments (Atom)\n'
#  'Thanks for Your Support\n'
#  'Your contributions help keep this site strong, independent, and '
#  'ad-free!Click this "PayPal" icon to contribute:Or send your contribution via '
#  'snail mail:Rex Parkerc/o Michael Sharp54 Matthews StBinghamton, NY '
#  '13905Thank you!Why Support This Site?\n'
#  'American Red Crosswords\n'
#  "A collection of 24 original puzzles to benefit the American Red Cross's "
#  'Disaster Relief Fund. Edited by Patrick Blindauer and with an introduction '
#  'by Will Shortz. Donate, download, solve!\n'
#  'Parker House Roll Call\n'
#  'Independent Puzzles\n'
#  'American Values Club xword (ed. Ben Tausig)\n'
#  'Crossword Nation (Liz Gorski)\n'
#  'Fireball Crosswords (ed. Peter Gordon)\n'
#  'Glutton for Pun (Erik Agard)\n'
#  'Andy Kravis, Cruciverbalist-at-Law\n'
#  'Grids These Days (Paolo Pasco)\n'
#  'Brendan Emmett Quigley (New every M/Th)\n'
#  'Daily Crossword Blogs\n'
#  'Diary of a Crossword Fiend\n'
#  'Other Crossword Sites\n'
#  'Cruciverb.com\n'
#  '"The Week" crossword (Peter Gordon)\n'
#  'Twisted But Fair (Merl Reagle)\n'
#  "Tyler Hinman's Blog\n"
#  "Stan Newman's Crossword Land\n"
#  'Pat Tricks: The puzzling art of puzzles and art (Patrick Merrell)\n'
#  'Triple Play Puzzles: Puzzles by Trip Payne\n'
#  'Ellen Ripstein: Putting the "blah blah blah" in blog\n'
#  "Ephraim's Crossword Puzzle Pointers\n"
#  "Will Johnston's Puzzle Pointers\n"
#  'About Me\n'
#  'Rex ParkerConfluence, New YorkI am the Greatest Crossword Solver in the '
#  'Universe (when I co-solve with my wife)! (2017 Pairs Division Champions, '
#  'Lollapuzzoola Crossword Tournament)\n'
#  '***SYNDICATED SOLVERS!!!***\n'
#  'The "SYNDICATED PUZZLE" link is up top, right above the banner\n'
#  'Contact Me\n'
#  'rexparker [at] icloud [dot] com\n'
#  'My Other Blogs\n'
#  'Pop Sensation — Vintage Paperbacks and Other Cultural Detritus\n'
#  "Sandy Davenport (wife's blog)\n"
#  'Do Me!\n'
#  '"Endless Fun" — a strange disappearing act by Rex Parker, 4/1/11\n'
#  '"Inside Dope, Part 2" — a mind-altering puzzle for the Holiday Season by '
#  'Michael Sharp, 12/25/09\n'
#  '"20 Years of Detention" — a "Simpsons" 20th anniversary puzzle by Patrick '
#  'Blindauer and Michael Sharp, 12/17/09\n'
#  '"And They\'re Off…" — a breezy midweek freebie by Michael Sharp, 12/9/09\n'
#  '"Aces!" — an offseason baseball puzzle by Michael Sharp, 11/30/09\n'
#  '"Star Turns" — a puzzle for Christina Applegate\'s breast cancer foundation '
#  'by Michael Sharp, 11/25/09\n'
#  '"King of the Blog" — a blog-themed birthday puzzle by Andrea Carla Michaels '
#  'and Doug Peterson, 11/26/09\n'
#  '"Happy Birthday, Kevin" — a birthday puzzle for a top-notch constructor by '
#  'Caleb Madison and Michael Sharp, 9/21/09\n'
#  '"Almost a Pangram" — a 2009 Inauguration puzzle by Ashish Vengsarkar, '
#  '1/20/09\n'
#  '"Don\'t Blink" — a VP debate themed puzzle by Michael Sharp and Angela Olson '
#  'Halsted, 10/7/08\n'
#  'Blog Archive\n'
#  '►\n'
#  '2018\n'
#  '(152)\n'
#  '►\n'
#  'June\n'
#  '(1)\n'
#  '►\n'
#  'May\n'
#  '(31)\n'
#  '►\n'
#  'April\n'
#  '(30)\n'
#  '►\n'
#  'March\n'
#  '(31)\n'
#  '►\n'
#  'February\n'
#  '(28)\n'
#  '►\n'
#  'January\n'
#  '(31)\n'
#  '►\n'
#  '2017\n'
#  '(365)\n'
#  '►\n'
#  'December\n'
#  '(31)\n'
#  '►\n'
#  'November\n'
#  '(30)\n'
#  '►\n'
#  'October\n'
#  '(31)\n'
#  '►\n'
#  'September\n'
#  '(30)\n'
#  '►\n'
#  'August\n'
#  '(31)\n'
#  '►\n'
#  'July\n'
#  '(31)\n'
#  '►\n'
#  'June\n'
#  '(30)\n'
#  '►\n'
#  'May\n'
#  '(31)\n'
#  '►\n'
#  'April\n'
#  '(30)\n'
#  '►\n'
#  'March\n'
#  '(31)\n'
#  '►\n'
#  'February\n'
#  '(28)\n'
#  '►\n'
#  'January\n'
#  '(31)\n'
#  '►\n'
#  '2016\n'
#  '(366)\n'
#  '►\n'
#  'December\n'
#  '(31)\n'
#  '►\n'
#  'November\n'
#  '(30)\n'
#  '►\n'
#  'October\n'
#  '(31)\n'
#  '►\n'
#  'September\n'
#  '(30)\n'
#  '►\n'
#  'August\n'
#  '(31)\n'
#  '►\n'
#  'July\n'
#  '(31)\n'
#  '►\n'
#  'June\n'
#  '(30)\n'
#  '►\n'
#  'May\n'
#  '(31)\n'
#  '►\n'
#  'April\n'
#  '(30)\n'
#  '►\n'
#  'March\n'
#  '(31)\n'
#  '►\n'
#  'February\n'
#  '(29)\n'
#  '►\n'
#  'January\n'
#  '(31)\n'
#  '▼\n'
#  '2015\n'
#  '(367)\n'
#  '►\n'
#  'December\n'
#  '(31)\n'
#  '►\n'
#  'November\n'
#  '(30)\n'
#  '►\n'
#  'October\n'
#  '(31)\n'
#  '►\n'
#  'September\n'
#  '(30)\n'
#  '►\n'
#  'August\n'
#  '(31)\n'
#  '►\n'
#  'July\n'
#  '(32)\n'
#  '►\n'
#  'June\n'
#  '(30)\n'
#  '►\n'
#  'May\n'
#  '(32)\n'
#  '►\n'
#  'April\n'
#  '(30)\n'
#  '►\n'
#  'March\n'
#  '(31)\n'
#  '▼\n'
#  'February\n'
#  '(28)\n'
#  "Bluebeard's Castle librettist Balázs / SAT 2-28-15...\n"
#  'True Blood vampire Northman / FRI 2-27-15 / Prefix...\n'
#  'Soap star Deborah / THU 2-26-15 / Eponymous Soviet...\n'
#  'Trevor of NBA / WED 2-25-15 / Part of rico roja / ...\n'
#  "Anthony's former partner in radio / TUE 2-24-15 / ...\n"
#  'Gossip spreader / MON 2-23-15 / Pilgrim to Mecca /...\n'
#  'Painter Uccello / SUN 2-22-15 / Four-legged orphan...\n'
#  'Italian city near Slovenian border / SAT 2-21-15 /...\n'
#  "Glassmaker's oven / FRI 2-20-15 / Orphan in Byron'...\n"
#  'Chinese-American fashion icon / THU 2-19-15 / Game...\n'
#  'Mollycoddle Dwayne Johnson / WED 2-18-15 / Onetime...\n'
#  '1960s Borgnine sitcom title role / TUE 2-17-15 / C...\n'
#  'French market town / MON 2-16-15 / Nobles above vi...\n'
#  'Foe of Mr. Fantastic in comics / SUN 2-15-15 / Col...\n'
#  'Top-selling app of 2010 / SAT 2-14-15 / 2011 Flo R...\n'
#  'Philosopher Robert who wrote Sceptical Chymist / F...\n'
#  'Adriatic peninsula shared by Italy Slovenia Croati...\n'
#  'Suffragist Carrie Chapman / WED 2-11-15 / Overzeal...\n'
#  'Flag carrier of Japan / TUE 2-10-15 / Where rednec...\n'
#  'Othello evildoer / MON 2-9-15 / Tree that yields c...\n'
#  "Ahab's father / SUN 2-8-15 / Princess of Power fro...\n"
#  'Hit radio comedy about bridge--playing couple / SA...\n'
#  'Star Wars surname / FRI 2-6-15 / Colonial heretic ...\n'
#  '1953 hit for Julius La Rosa / THU 2-5-15 / Half-be...\n'
#  "Happily old style / WED 2-4-15 / Desk jockey's hap...\n"
#  'Small eel / TUE 2-3-15 / Doughnuts mathematically ...\n'
#  'William who played Hopalong Cassidy in old western...\n'
#  'Nymph jilted by Paris / SUN 2-1-15 / Roman guardia...\n'
#  '►\n'
#  'January\n'
#  '(31)\n'
#  '►\n'
#  '2014\n'
#  '(366)\n'
#  '►\n'
#  'December\n'
#  '(31)\n'
#  '►\n'
#  'November\n'
#  '(30)\n'
#  '►\n'
#  'October\n'
#  '(32)\n'
#  '►\n'
#  'September\n'
#  '(30)\n'
#  '►\n'
#  'August\n'
#  '(31)\n'
#  '►\n'
#  'July\n'
#  '(31)\n'
#  '►\n'
#  'June\n'
#  '(30)\n'
#  '►\n'
#  'May\n'
#  '(31)\n'
#  '►\n'
#  'April\n'
#  '(30)\n'
#  '►\n'
#  'March\n'
#  '(31)\n'
#  '►\n'
#  'February\n'
#  '(28)\n'
#  '►\n'
#  'January\n'
#  '(31)\n'
#  '►\n'
#  '2013\n'
#  '(366)\n'
#  '►\n'
#  'December\n'
#  '(31)\n'
#  '►\n'
#  'November\n'
#  '(30)\n'
#  '►\n'
#  'October\n'
#  '(31)\n'
#  '►\n'
#  'September\n'
#  '(31)\n'
#  '►\n'
#  'August\n'
#  '(31)\n'
#  '►\n'
#  'July\n'
#  '(31)\n'
#  '►\n'
#  'June\n'
#  '(30)\n'
#  '►\n'
#  'May\n'
#  '(31)\n'
#  '►\n'
#  'April\n'
#  '(30)\n'
#  '►\n'
#  'March\n'
#  '(31)\n'
#  '►\n'
#  'February\n'
#  '(28)\n'
#  '►\n'
#  'January\n'
#  '(31)\n'
#  '►\n'
#  '2012\n'
#  '(367)\n'
#  '►\n'
#  'December\n'
#  '(31)\n'
#  '►\n'
#  'November\n'
#  '(30)\n'
#  '►\n'
#  'October\n'
#  '(32)\n'
#  '►\n'
#  'September\n'
#  '(30)\n'
#  '►\n'
#  'August\n'
#  '(31)\n'
#  '►\n'
#  'July\n'
#  '(31)\n'
#  '►\n'
#  'June\n'
#  '(30)\n'
#  '►\n'
#  'May\n'
#  '(31)\n'
#  '►\n'
#  'April\n'
#  '(30)\n'
#  '►\n'
#  'March\n'
#  '(31)\n'
#  '►\n'
#  'February\n'
#  '(29)\n'
#  '►\n'
#  'January\n'
#  '(31)\n'
#  '►\n'
#  '2011\n'
#  '(368)\n'
#  '►\n'
#  'December\n'
#  '(31)\n'
#  '►\n'
#  'November\n'
#  '(31)\n'
#  '►\n'
#  'October\n'
#  '(31)\n'
#  '►\n'
#  'September\n'
#  '(29)\n'
#  '►\n'
#  'August\n'
#  '(31)\n'
#  '►\n'
#  'July\n'
#  '(31)\n'
#  '►\n'
#  'June\n'
#  '(30)\n'
#  '►\n'
#  'May\n'
#  '(32)\n'
#  '►\n'
#  'April\n'
#  '(32)\n'
#  '►\n'
#  'March\n'
#  '(31)\n'
#  '►\n'
#  'February\n'
#  '(28)\n'
#  '►\n'
#  'January\n'
#  '(31)\n'
#  '►\n'
#  '2010\n'
#  '(370)\n'
#  '►\n'
#  'December\n'
#  '(31)\n'
#  '►\n'
#  'November\n'
#  '(30)\n'
#  '►\n'
#  'October\n'
#  '(31)\n'
#  '►\n'
#  'September\n'
#  '(30)\n'
#  '►\n'
#  'August\n'
#  '(31)\n'
#  '►\n'
#  'July\n'
#  '(31)\n'
#  '►\n'
#  'June\n'
#  '(32)\n'
#  '►\n'
#  'May\n'
#  '(31)\n'
#  '►\n'
#  'April\n'
#  '(30)\n'
#  '►\n'
#  'March\n'
#  '(31)\n'
#  '►\n'
#  'February\n'
#  '(28)\n'
#  '►\n'
#  'January\n'
#  '(34)\n'
#  '►\n'
#  '2009\n'
#  '(383)\n'
#  '►\n'
#  'December\n'
#  '(34)\n'
#  '►\n'
#  'November\n'
#  '(33)\n'
#  '►\n'
#  'October\n'
#  '(31)\n'
#  '►\n'
#  'September\n'
#  '(31)\n'
#  '►\n'
#  'August\n'
#  '(32)\n'
#  '►\n'
#  'July\n'
#  '(32)\n'
#  '►\n'
#  'June\n'
#  '(31)\n'
#  '►\n'
#  'May\n'
#  '(32)\n'
#  '►\n'
#  'April\n'
#  '(32)\n'
#  '►\n'
#  'March\n'
#  '(32)\n'
#  '►\n'
#  'February\n'
#  '(29)\n'
#  '►\n'
#  'January\n'
#  '(34)\n'
#  '►\n'
#  '2008\n'
#  '(395)\n'
#  '►\n'
#  'December\n'
#  '(30)\n'
#  '►\n'
#  'November\n'
#  '(36)\n'
#  '►\n'
#  'October\n'
#  '(32)\n'
#  '►\n'
#  'September\n'
#  '(32)\n'
#  '►\n'
#  'August\n'
#  '(33)\n'
#  '►\n'
#  'July\n'
#  '(33)\n'
#  '►\n'
#  'June\n'
#  '(31)\n'
#  '►\n'
#  'May\n'
#  '(34)\n'
#  '►\n'
#  'April\n'
#  '(34)\n'
#  '►\n'
#  'March\n'
#  '(37)\n'
#  '►\n'
#  'February\n'
#  '(30)\n'
#  '►\n'
#  'January\n'
#  '(33)\n'
#  '►\n'
#  '2007\n'
#  '(380)\n'
#  '►\n'
#  'December\n'
#  '(33)\n'
#  '►\n'
#  'November\n'
#  '(32)\n'
#  '►\n'
#  'October\n'
#  '(31)\n'
#  '►\n'
#  'September\n'
#  '(30)\n'
#  '►\n'
#  'August\n'
#  '(31)\n'
#  '►\n'
#  'July\n'
#  '(31)\n'
#  '►\n'
#  'June\n'
#  '(31)\n'
#  '►\n'
#  'May\n'
#  '(31)\n'
#  '►\n'
#  'April\n'
#  '(33)\n'
#  '►\n'
#  'March\n'
#  '(36)\n'
#  '►\n'
#  'February\n'
#  '(29)\n'
#  '►\n'
#  'January\n'
#  '(32)\n'
#  '►\n'
#  '2006\n'
#  '(105)\n'
#  '►\n'
#  'December\n'
#  '(33)\n'
#  '►\n'
#  'November\n'
#  '(30)\n'
#  '►\n'
#  'October\n'
#  '(36)\n'
#  '►\n'
#  'September\n'
#  '(6)\n'
#  'Rex Parker Does the NYT Crossword Puzzle\n'
#  '© Free Blogger Templates\n'
#  'Columnus by Ourblogtemplates.com 2008\n'
#  'Back to TOP')

# %%
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a4efa65f-ec53-4d08-9be0-51badbecd221">Loading BokehJS ...</span>
#     </div>
# 256

# %%
# Out:
# ['ColumnDataSource',
#  'HoverTool',
#  'In',
#  'LOAD_CACHED',
#  'OpenURL',
#  'Out',
#  'TapTool',
#  '_',
#  '_4',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'figure',
#  'get_ipython',
#  'mine_list',
#  'os',
#  'output_file',
#  'output_notebook',
#  'quit',
#  'show']

# %%
try:
    assert os.path.isfile('../BenchmarkCorpus/benchmarks_ranked.p')
    benchmarks_ranked = pickle.load(open('../BenchmarkCorpus/benchmarks_ranked.p','rb'))

    benchmarks_unranked = pickle.load(open('../BenchmarkCorpus/benchmarks.p','rb'))# as f: pickle.dump(benchmarks,f)
    benchmarks = [ b[1] for b in benchmarks_ranked ]
    urlDats = []
    urlDats.extend(benchmarks_ranked)
    print('benchmarks loaded')
except:
    pass
urlDats
# Out:
# benchmarks loaded
# [('upgoer5_corpus',
#   {'link': 'http://splasho.com/upgoer5/library.php',
#    'wcount': 67298,
#    'english': True,
#    'uniqueness': 0.02861388690918465,
#    'info_density': 0.024379501220165467,
#    'scaled_info_density': 3.6226189812721727e-07,
#    'sp': 0.06790958242825419,
#    'ss': 0.49938406998918644,
#    'standard': 6.0,
#    'gf': 10.269783596852868,
#    'penalty': 6.361771729201701}),
#  ('the readability of science decr over time',
#   {'link': 'https://elifesciences.org/download/aHR0cHM6Ly9jZG4uZWxpZmVzY2llbmNlcy5vcmcvYXJ0aWNsZXMvMjc3MjUvZWxpZmUtMjc3MjUtdjIucGRm/elife-27725-v2.pdf?_hash=WA%2Fey48HnQ4FpVd6bc0xCTZPXjE5ralhFP2TaMBMp1c%3D',
#    'wcount': 180875,
#    'english': True,
#    'uniqueness': 0.016489417841599772,
#    'info_density': 2.1511621653598357e-05,
#    'scaled_info_density': 1.1893087299847052e-10,
#    'sp': 0.09111590319261478,
#    'ss': 0.42641454123014083,
#    'standard': 13.0,
#    'gf': 10.027777398981875,
#    'penalty': 13.256468115939589}),
#  ('science of writing',
#   {'link': 'https://cseweb.ucsd.edu/~swanson/papers/science-of-writing.pdf',
#    'wcount': 71352,
#    'english': True,
#    'uniqueness': 0.02318294795511034,
#    'info_density': 5.3471646659358877e-05,
#    'scaled_info_density': 7.494064169099517e-10,
#    'sp': 0.10379964316459184,
#    'ss': 0.4251460908615604,
#    'standard': 14.0,
#    'gf': 12.181340587789323,
#    'penalty': 14.386199037163559}),
#  ('post modern essay generator',
#   {'link': 'http://www.elsewhere.org/pomo/',
#    'wcount': 1242,
#    'english': True,
#    'uniqueness': 0.3916083916083916,
#    'info_density': 0.0028192176670973805,
#    'scaled_info_density': 2.269901503299018e-06,
#    'sp': 0.11777310924369747,
#    'ss': 0.4777731092436974,
#    'standard': 18.0,
#    'gf': 19.436241610738257,
#    'penalty': 25.72921254369105})]

# %%
import pickle
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# Out:
# [{'link': '/home/jovyan/Examples/photosysnthesis_duckduckgo_2.html', 'wcount': 1717, 'english': True, 'science': False, 'uniqueness': 0.3700061462814997, 'info_density': 0.002079542500649857, 'scaled_info_density': 1.2111488064355602e-06, 'sp': 0.09656941232283704, 'ss': 0.4466976516634052, 'standard': 16.0, 'gf': 19.725053635280098, 'penalty': 18.40579388162629}, {'link': '/home/jovyan/Examples/photosysnthesis_duckduckgo_3.html', 'wcount': 5042, 'english': True, 'science': False, 'uniqueness': 0.21885313531353134, 'info_density': 0.0007436326454731362, 'scaled_info_density': 1.4748763297761527e-07, 'sp': 0.14614884283140397, 'ss': 0.44940104551821175, 'standard': 14.0, 'gf': 14.713294889640089, 'penalty': 14.95219733316966}, {'link': '/home/jovyan/Examples/photosysnthesis_duckduckgo_9.html', 'wcount': 634, 'english': True, 'science': False, 'uniqueness': 0.45210084033613446, 'info_density': 0.00574300071787509, 'scaled_info_density': 9.058360753746199e-06, 'sp': 0.17166241496598644, 'ss': 0.42740221088435354, 'standard': 7.0, 'gf': 17.225582137161087, 'penalty': 12.711855694430884}, {'link': '/home/jovyan/Examples/photosysnthesis_google_3.html', 'wcount': 5042, 'english': True, 'science': False, 'uniqueness': 0.21885313531353134, 'info_density': 0.0007436326454731362, 'scaled_info_density': 1.4748763297761527e-07, 'sp': 0.14614884283140397, 'ss': 0.44940104551821175, 'standard': 14.0, 'gf': 14.713294889640089, 'penalty': 14.95219733316966}, {'link': '/home/jovyan/Examples/photosysnthesis_google_5.html', 'wcount': 634, 'english': True, 'science': False, 'uniqueness': 0.45210084033613446, 'info_density': 0.00574300071787509, 'scaled_info_density': 9.058360753746199e-06, 'sp': 0.17166241496598644, 'ss': 0.42740221088435354, 'standard': 7.0, 'gf': 17.225582137161087, 'penalty': 12.711855694430884}, {'link': '/home/jovyan/Examples/prancercise philosophy_duckduckgo_9.html', 'wcount': 1268, 'english': True, 'science': False, 'uniqueness': 0.488034188034188, 'info_density': 0.003103582050950472, 'scaled_info_density': 2.4476199139987948e-06, 'sp': 0.12750365625365628, 'ss': 0.3728071253071252, 'standard': 15.0, 'gf': 20.176614881439082, 'penalty': 18.08861822228032}, {'link': '/home/jovyan/Examples/prancercise philosophy_wikipedia_14.html', 'wcount': 140563, 'english': True, 'science': False, 'uniqueness': 0.13968518869713636, 'info_density': 0.009638837738779497, 'scaled_info_density': 6.85730792511507e-08, 'sp': 0.08115143387205986, 'ss': 0.4099382010159768, 'standard': 12.0, 'gf': 15.872753002648864, 'penalty': 14.42746613621247}, {'link': '/home/jovyan/Examples/prancercise philosophy_wikipedia_18.html', 'wcount': 2261, 'english': True, 'science': False, 'uniqueness': 0.45974155069582506, 'info_density': 0.0016628559551028891, 'scaled_info_density': 7.35451550244533e-07, 'sp': 0.05535495649132008, 'ss': 0.44781746031746006, 'standard': 21.0, 'gf': 21.58698795180723, 'penalty': 21.796666392712396}, {'link': '/home/jovyan/Examples/prancercise philosophy_wikipedia_24.html', 'wcount': 17419, 'english': True, 'science': False, 'uniqueness': 0.23069173942243115, 'info_density': 0.00023981294590219628, 'scaled_info_density': 1.3767319932383963e-08, 'sp': 0.07002999275559499, 'ss': 0.45799965617664273, 'standard': 11.0, 'gf': 16.621970495882458, 'penalty': 14.339014896873467}, {'link': '/home/jovyan/Examples/prancercise philosophy_wikipedia_34.html', 'wcount': 965, 'english': True, 'science': False, 'uniqueness': 0.5261538461538462, 'info_density': 0.0044994375703037125, 'scaled_info_density': 4.662629606532344e-06, 'sp': 0.19101519395637043, 'ss': 0.5786563110092522, 'standard': 7.0, 'gf': 23.353846153846156, 'penalty': 15.946594581888702}, {'link': '/home/jovyan/Examples/prancercise philosophy_wikipedia_37.html', 'wcount': 10577, 'english': True, 'science': False, 'uniqueness': 0.2583052985702271, 'info_density': 0.00041356492969396195, 'scaled_info_density': 3.910039989542989e-08, 'sp': 0.11514689608937338, 'ss': 0.48080421432580067, ' ...

# %% [markdown]
# # Wrangle unwieldly dict of dicts and coerce into Pandas Data Frame
# For a statistics and plotting friendly data base like type.

# %%
#unravel = url_text = crude_text = list_per_links
#crude_text = list(filter(lambda x: len(x)!=0, crude_text))
import pandas as pd

#ct = pd.DataFrame(unravel,columns=dfs[0].keys())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-9e0b535b5226> in <module>()
#       3 import pandas as pd
#       4
# ----> 5 ct = pd.DataFrame(unravel,columns=dfs[0].keys())
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0

# %%
list(ct.columns.values)
df2 = ct.loc[ct['keyword'] == 'unicorn', ['fkg']]
ct = ct.drop(ct[ct.fkg > 100].index)
df2 = ct.loc[ct['keyword'] == 'unicorn', ['fkg']]

# %%
print(QUERY_LIST)
links = [ f['link'] for f in unravel ]

# %%
print(data_frames.columns)
df = data_frames.T

# %%
source = ColumnDataSource(data=dict(
    y=[f['gf'] for f in unravel],
    x=[ f['sp'] for f in unravel ],
    desc=[ f['link'] for f in unravel ],
))

hover = HoverTool(tooltips=[
    ("index", "$index"),
    ("(x,y)", "($x, $y)"),
    ("desc", "@desc"),
])



p = figure(plot_width=1000, plot_height=1000, tools=["tap","hover"],
           title="For Against versus complexity")


p.circle('x', 'y', size=8, source=source)


url = "@desc"
taptool = p.select(type=TapTool)
taptool.callback = OpenURL(url=url)

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="625d37f8-492c-490a-b86a-a0de40783f4e"></div>
# </div>

# %%
source = ColumnDataSource(data=dict(
    y=[f['gf'] for f in unravel],
    x=[ f['info_density'] for f in unravel ],
    desc=[ f['link'] for f in unravel ],
))

hover = HoverTool(tooltips=[
    ("index", "$index"),
    ("(x,y)", "($x, $y)"),
    ("desc", "@desc"),
])



p = figure(plot_width=1000, plot_height=1000, tools=["tap","hover"],
           title="info_density versus complexity")


p.circle('x', 'y', size=8, source=source)


url = "@desc"
taptool = p.select(type=TapTool)
taptool.callback = OpenURL(url=url)

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="834eaa22-f151-48ce-a050-1260473687f8"></div>
# </div>

# %%
source = ColumnDataSource(data=dict(
    x=[ f['gf'] for f in unravel if 'fkg' in f.keys() ],
    y=[ f['info_density'] for f in unravel if 'info_density' in f.keys()],
    links=links,
))


hover = HoverTool(tooltips=[
    ("index", "$index"),
    ("(x,y)", "($x, $y)"),
    ("links", "@links"),
])



p = figure(plot_width=1000, plot_height=1000, tools=["tap","hover"],
           title="Conciseness versus Complexity")


p.circle('x', 'y', size=8, source=source)


url = "@links"
taptool = p.select(type=TapTool)
taptool.callback = OpenURL(url=url)

show(p)
# Out:
# /opt/conda/lib/python3.6/site-packages/bokeh/models/sources.py:110: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 0), ('y', 90)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="d06bd611-97e9-46b7-a313-4a2c27f7c841"></div>
# </div>

# %%
# Out:
#    english       gf info_density  \
# 0     True  19.7251   0.00207954
# 0     True  19.7251   0.00207954
# 0     True  14.7133  0.000743633
# 0     True  17.2256     0.005743
# 0     True  14.7133  0.000743633
# 0     True  17.2256     0.005743
# 0     True  20.1766   0.00310358
# 0     True  15.8728   0.00963884
# 0     True   21.587   0.00166286
# 0     True   16.622  0.000239813
# 0     True  23.3538   0.00449944
# 0     True  13.5458  0.000413565
# 0     True  48.6452   0.00659285
# 0     True   16.092   0.00940102
# 0     True  34.5304   0.00434704
# 0     True  21.8819   0.00244449
# 0     True  18.3665   0.00162481
# 0     5042
# 0      634
# 0     1268
# 0   140563
# 0     2261
# 0    17419
# 0      965
# 0    10577
# 0   228962
# 0   145193
# 0      620
# 0     1604
# 0     2530
# 0     2292
# 0     1944
# 0     2091
# 0      835
# 0      529
# 0      545
# 0     1942
# 0      506
# 0     4176
# 0     1942
# 0     1166
# 0     1314
# 0     1036
# ..     ...
# 0     2530
# 0     2292
# 0     1944
# 0     2091
# 0      835
# 0      529
# 0      545
# 0     1942
# 0      506
# 0     4176
# 0     1942
# 0     1166
# 0     1314
# 0     1036
# 0     1505
# 0     1373
# 0      571
# 0    11101
# 0     8610
# 0    21128
# 0    11122
# 0     9285
# 0     9630
# 0      569
# 0     2690
# 0     1377
# 0     2131
# 0     7570
# 0    10418
# 0      822
#
# [91 rows x 12 columns]

# %%
QUERY_LIST = [ u['link'].split("/")[-1].split("_")[0] for u in unravel ]
print(QUERY_LIST)
ENGINE_LIST = [ u['link'].split("/")[-1].split("_")[-1] for u in unravel ]
print(ENGINE_LIST)
# Out:
# ['photosysnthesis', 'photosysnthesis', 'photosysnthesis', 'photosysnthesis', 'photosysnthesis', 'prancercise philosophy', 'prancercise philosophy', 'prancercise philosophy', 'prancercise philosophy', 'prancercise philosophy', 'prancercise philosophy', 'prancercise philosophy', 'prancercise philosophy', 'prancercise philosophy', 'reality TV', 'reality TV', 'reality TV', 'reality TV', 'reality TV', 'reality TV', 'reality TV', 'reality TV', 'respiration', 'respiration', 'respiration', 'respiration', 'respiration', 'respiration', 'respiration', 'respiration', 'respiration', 'respiration', 's jarvis optogeneticsscholar0.html', 's jarvis optogeneticsscholar1.html', 's jarvis optogeneticsscholar2.html', 's jarvis optogeneticsscholar4.html', 's jarvis optogeneticsscholar5.html', 's jarvis optogeneticsscholar6.html', 's jarvis optogeneticsscholar8.html', 's jarvis optogeneticsscholar9.html', 'scrook rgerkin neuronduckduckgo2.html', 'scrook rgerkin neuronduckduckgo3.html', 'scrook rgerkin neuronduckduckgo6.html', 'scrook rgerkin neuronduckduckgo10.html', 'scrook rgerkin neuronduckduckgo14.html', 'photosysnthesis', 'photosysnthesis', 'photosysnthesis', 'photosysnthesis', 'photosysnthesis', 'prancercise philosophy', 'prancercise philosophy', 'prancercise philosophy', 'prancercise philosophy', 'prancercise philosophy', 'prancercise philosophy', 'prancercise philosophy', 'prancercise philosophy', 'prancercise philosophy', 'reality TV', 'reality TV', 'reality TV', 'reality TV', 'reality TV', 'reality TV', 'reality TV', 'reality TV', 'respiration', 'respiration', 'respiration', 'respiration', 'respiration', 'respiration', 'respiration', 'respiration', 'respiration', 'respiration', 's jarvis optogeneticsscholar0.html', 's jarvis optogeneticsscholar1.html', 's jarvis optogeneticsscholar2.html', 's jarvis optogeneticsscholar4.html', 's jarvis optogeneticsscholar5.html', 's jarvis optogeneticsscholar6.html', 's jarvis optogeneticsscholar8.html', 's jarvis optogeneticsscholar9.html', 'scrook rgerkin neuronduckduckgo2.html', 'scrook rgerkin neuronduckduckgo3.html', 'scrook rgerkin neuronduckduckgo6.html', 'scrook rgerkin neuronduckduckgo10.html', 'scrook rgerkin neuronduckduckgo14.html']
# ['2.html', '3.html', '9.html', '3.html', '5.html', '9.html', '14.html', '18.html', '24.html', '34.html', '37.html', '47.html', '48.html', '52.html', '21.html', '34.html', '41.html', '70.html', '79.html', '82.html', '85.html', '96.html', '7.html', '10.html', '12.html', '15.html', '18.html', '21.html', '22.html', '26.html', '30.html', '31.html', 's jarvis optogeneticsscholar0.html', 's jarvis optogeneticsscholar1.html', 's jarvis optogeneticsscholar2.html', 's jarvis optogeneticsscholar4.html', 's jarvis optogeneticsscholar5.html', 's jarvis optogeneticsscholar6.html', 's jarvis optogeneticsscholar8.html', 's jarvis optogeneticsscholar9.html', 'scrook rgerkin neuronduckduckgo2.html', 'scrook rgerkin neuronduckduckgo3.html', 'scrook rgerkin neuronduckduckgo6.html', 'scrook rgerkin neuronduckduckgo10.html', 'scrook rgerkin neuronduckduckgo14.html', '2.html', '3.html', '9.html', '3.html', '5.html', '9.html', '14.html', '18.html', '24.html', '34.html', '37.html', '47.html', '48.html', '52.html', '21.html', '34.html', '41.html', '70.html', '79.html', '82.html', '85.html', '96.html', '7.html', '10.html', '12.html', '15.html', '18.html', '21.html', '22.html', '26.html', '30.html', '31.html', 's jarvis optogeneticsscholar0.html', 's jarvis optogeneticsscholar1.html', 's jarvis optogeneticsscholar2.html', 's jarvis optogeneticsscholar4.html', 's jarvis optogeneticsscholar5.html', 's jarvis optogeneticsscholar6.html', 's jarvis optogeneticsscholar8.html', 's jarvis optogeneticsscholar9.html', 'scrook rgerkin neuronduckduckgo2.html', 'scrook rgerkin neuronduckduckgo3.html', 'scrook rgerkin neuronduckduckgo6.html', 'scrook rgerkin neuronduckduckgo10.html', 'scrook rgerkin neuronduckduckgo14.html']

# %%
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
unravel = list(filter(lambda x: len(x)!=0, unravel))
for outer,search_query in enumerate(QUERY_LIST):    
    complexity = ct.loc[ct['keyword'] == search_query, ['gf']]
    complexity = complexity['gf'].values

    
    rank = [ f['link_rank'] for f in unravel if f['keyword'] == search_query ]#
    print(len(complexity),len(rank))
    if len(complexity)>0 and len(rank)>0:
        if len(complexity)==len(rank):
            plt.figure()


            df = pd.DataFrame({'complexity': complexity,'rank': rank})
            plt.title(str('link rank vs complexity ')+str(search_query))
            ax = sns.regplot(x="rank",y="complexity", data=df)

legend = ax.legend(loc='upper center', shadow=True)
plt.savefig('sentiment_vs_complexity{0}.png'.format(search_query))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-1d1e9cd8a314> in <module>()
#       4 unravel = list(filter(lambda x: len(x)!=0, unravel))
#       5 for outer,search_query in enumerate(QUERY_LIST):
# ----> 6     complexity = ct.loc[ct['keyword'] == search_query, ['gf']]
#       7     complexity = complexity['gf'].values
#       8
#
# NameError: name 'ct' is not defined

# %%
import seaborn as sns
import pandas as pd
import statsmodels.api as sm

import numpy as np
import pandas as pd


for outer,search_query in enumerate(QUERY_LIST):    
    complexity = [ f['fkg'] for f in unravel if f['keyword'] == search_query ]
    #complexity = ctu.loc[ctu['keyword'] == search_query, ['fkg']]
    #complexity = complexity['fkg'].values
    sent = [ f['sp'] for f in unravel if f['keyword'] == search_query ]
    if len(complexity)>0 and len(sent)>0:
        if len(complexity)==len(sent):


            df = pd.DataFrame({'complexity': complexity,'sent': sent})
            plt.figure()
            plt.title(str('for/against vs complexity ')+str(search_query))
            ax = sns.regplot(x="sent",y="complexity", data=df)
legend = ax.legend(loc='upper center', shadow=True)
plt.savefig('sentiment_vs_complexity{0}.png'.format(search_query))
plt.show()

# %%
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
for outer,search_query in enumerate(QUERY_LIST):    
    complexity = [ f['fkg'] for f in unravel if f['keyword'] == search_query ]
    sub = [ f['ss'] for f in unravel if f['keyword'] == search_query ]
    if len(complexity)>0 and len(sent)>0:
        df = pd.DataFrame({'complexity': complexity,'sub': sub})
        plt.figure()
        plt.title(str('subjectivity vs complexity ')+str(search_query))
        ax = sns.regplot(x="sub",y="complexity", data=df)


legend = ax.legend(loc='upper center', shadow=True)
plt.savefig('sentiment_vs_complexity{0}.png'.format(search_query))
plt.show()

# %%
ENGINE_LIST = utils_and_paramaters.engine_dict_list()
crude_text = list(filter(lambda x: len(x)!=0, crude_text))

gsc_text = list(filter(lambda x: x['se'] == 'gScholar_', crude_text))
bibg_text = list(filter(lambda x: x['se'] == 'bing_', crude_text))

for q in ENGINE_LIST:
    check = list(filter(lambda x: x['se'] == q, crude_text))

for q in QUERY_LIST:
    check = list(filter(lambda x: x['keyword'] == q, crude_text))
    
# total number of words
ents = ct['eofh']


droplist = []
droplist.append(ct.loc[10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-3c6409de50ec> in <module>()
#       1
# ----> 2 ENGINE_LIST = utils_and_paramaters.engine_dict_list()
#       3 crude_text = list(filter(lambda x: len(x)!=0, crude_text))
#       4
#       5 gsc_text = list(filter(lambda x: x['se'] == 'gScholar_', crude_text))
#
# NameError: name 'utils_and_paramaters' is not defined

# %%
urls = ct.values

# %% [markdown]
# # Unigram model expected value
# Entropies of texts

# %%
gm = sum([ v for k,v in giantmodel.items() ])    
probs = [ (float(v)/gm, k) for k,v in giantmodel.items() ]
probs = [ (p[0],p[1]) for p in probs if p[0] > 0.]
ents = {}
ent = 0
import math
for p in probs:
    if p[0] > 0.:
        ent -= p[0] * math.log(p[0], 2)
        ents[p[1]] = ent

#federate_frequencies =  []
yentropies = [ v['eofh'] for v in unravel ]
import numpy as np
print(np.mean(yentropies))
print(np.var(yentropies))

wns = [ x for x in range(0,len(ents)) ]
probs = [i[0] for i in probs]
import pandas as pd
d = {'words': wns, 'probs': probs}
df = pd.DataFrame(data=d)
ax = sns.regplot(x='words', y='probs', data=df)
plt.show()

# %% [markdown]
# Below: call system (bash) to programmatically convert this notebook to html,
# Such that tech illiterate people can view it in a browser (probably ipynb extension is essentially html anyway, but
# they probably don't realize this).

# %%
# !jupyter nbconvert Visualisation_search_terms_reading_levelGS0.ipynb --to html

# %%
import os
os.system('jupyter nbconvert Visualisation_search_terms_reading_levelGS0.ipynb --to html ')
# !pwd

# %%
stat_items = [ f for f in unravel ] 

unravel[0];
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_regression
from scipy.stats import pearsonr
import numpy as np

rfr = RandomForestRegressor(n_estimators=25)
lm = LinearRegression()

features = [ list(c.values())[0:-1] for c in crude_text ]
feature_labels = [ list(c.keys())[0:-1] for c in crude_text ]

# %%
# 3.       GMO/transgenics vs. text complexity
y = []
e = []
for outer,sq in enumerate(QUERY_LIST):    

    comp = sum([ f['fkg'] for f in unravel if f['keyword'] ==sq])
    entropy = sum([ f['eofh'] for f in unravel if f['keyword'] ==sq  ])
    y.append(comp)
    e.append(entropy)
plt.clf()
fig, ax = plt.subplots()
# Two subplots, the axes array is 1-d
width = 0.35       # the width of the bars
ind = [i for i,v in enumerate(QUERY_LIST)]
offset = [(i+width) for i,v in enumerate(ind)]
rects1 = ax.bar(offset[0], y[0] , width, color='r')# yerr=men_std)
rects2 = ax.bar(offset[1], y[1], width, color='g')#, yerr=women_std)
rects3 = ax.bar(offset[2], y[2], width, color='r')#, yerr=women_std)
rects4 = ax.bar(offset[3], y[3], width, color='b')#, yerr=women_std)
rects5 = ax.bar(offset[4], y[4], width, color='g')#, yerr=women_std)
rects6 = ax.bar(offset[5], y[4], width, color='b')#, yerr=women_std)




# add some text for labels, title and axes ticks
ax.set_ylabel('Complexity')
ax.set_title('Readability by search query and Search Engine')

ax.legend([rects1[0], rects2[0],rects3[0],rects4[0],rects5[0],rects6[0]], QUERY_LIST)
plt.show()
plt.clf()
fig, ax = plt.subplots()
# Two subplots, the axes array is 1-d
width = 0.35       # the width of the bars
rects1 = ax.bar(offset[0], e[0] , width, color='r')# yerr=men_std)
rects2 = ax.bar(offset[1], e[1], width, color='g')#, yerr=women_std)
rects3 = ax.bar(offset[2], e[2], width, color='r')#, yerr=women_std)
rects4 = ax.bar(offset[3], e[3], width, color='b')#, yerr=women_std)
rects5 = ax.bar(offset[4], e[4], width, color='g')#, yerr=women_std)
rects6 = ax.bar(offset[5], e[4], width, color='b')#, yerr=women_std)


ax.set_ylabel('Complexity')
ax.set_title('Entropy by search query and Search Engine')
ax.legend([rects1[0], rects2[0],rects3[0],rects4[0],rects5[0],rects6[0]], QUERY_LIST)


plt.show()

# %%
gsc_text = list(filter(lambda x: x['se'] == 'gScholar_', crude_text))
ddg_text = list(filter(lambda x: x['se'] == 'duckduckgo_', crude_text))
bing_text = list(filter(lambda x: x['se'] == 'bing_', crude_text))
gword_names = [ c['keyword'] for c in gsc_text ]
gsc_entropies = [e['eofh'] for e in gsc_text if e['se'] == 'gScholar_' ]
bing_entropies = [e['eofh'] for e in bing_text if e['se'] == 'bing_']
ddg_entropies = [e['eofh'] for e in ddg_text if e['se'] == 'duckduckgo_'] 
yahoo_entropies = [e['eofh'] for e in ddg_text if e['se'] == 'yahoo_'] 
google_entropies = [e['eofh'] for e in ddg_text if e['se'] == 'google_'] 

wns = [ x for x in range(0,len(gsc_text)) ]
plt.clf()
fig, ax = plt.subplots()

plt.plot([ x for x in range(0,len(gsc_entropies)) ],gsc_entropies,label='google scholar')
plt.plot([ x for x in range(0,len(ddg_entropies)) ],ddg_entropies,label='duck duck go')
plt.plot([ x for x in range(0,len(yahoo_entropies)) ],yahoo_entropies,label='yahoo')
plt.plot([ x for x in range(0,len(google_entropies)) ],google_entropies,label='google')
legend = ax.legend(loc='upper center')

plt.show()

all_entropies = [e['eofh'] for e in crude_text ] 
all_entropies = [e['eofh'] for e in crude_text ] 
plt.clf()
plt.plot([i for i,j in enumerate(all_entropies)],all_entropies)
plt.title('all entropies')
plt.show()
all_polarities =[e['sp'] for e in crude_text ] 

plt.clf()
plt.plot([i for i,j in enumerate(all_polarities)],all_polarities)
plt.title('all polarities')
plt.show()
print(len(unravel))
print(np.shape(unravel))


all_subjectivities =[e['ss'] for e in crude_text ] 

plt.clf()
plt.plot([i for i,j in enumerate(all_subjectivities)],all_subjectivities)
plt.title('all subjectivities')
plt.show()

# %% [markdown]
# Is entropy a good predictor of all other variables?
